# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
amphi_positions=pd.read_csv(r"C:\Users\ASUS\Desktop\3y\S2\machine learning\Project\Local\Data\ensia_gps_data .csv")
print(amphi_positions.head())
# Out:
#    id  year  section user  amphitheatre            module seat_block  \
# 0   2   3.0      NaN  NaN       Amphi 3  Manual Selection     Center
# 1   3   3.0      NaN  NaN         lab 8  Campus-wide Data        NaN
# 2   4   3.0      NaN  NaN  School entry  Campus-wide Data        NaN
# 3   5   3.0      NaN  NaN       Amphi 4  Manual Selection     Center
# 4   6   3.0      NaN  NaN          room  Campus-wide Data        NaN
#
#    seat_row  seat_column  latitude_mean  ...  sample_count  \
# 0       3.0          6.0      36.687824  ...             0
# 1       NaN          NaN      36.688127  ...             0
# 2       NaN          NaN      36.688729  ...             0
# 3       7.0          5.0      36.688630  ...             0
# 4       NaN          NaN      36.688630  ...             0
#
#                                     raw_gps_readings  \
# 0  [{'latitude': 36.687824, 'longitude': 2.86715,...
# 1  [{'latitude': 36.688126994584465, 'longitude':...
# 2  [{'latitude': 36.6886848, 'longitude': 2.86555...
# 3  [{'latitude': 36.68863, 'longitude': 2.86675, ...
# 4  [{'latitude': 36.68863, 'longitude': 2.86675, ...
#
#                                  collection_metadata  \
# 0  {'number_of_readings': 10, 'collection_duratio...
# 1  {'number_of_readings': 10, 'collection_duratio...
# 2  {'number_of_readings': 10, 'collection_duratio...
# 3  {'number_of_readings': 10, 'collection_duratio...
# 4  {'number_of_readings': 10, 'collection_duratio...
#
#                                    navigator_context  \
# 0  {'platform': 'Win32', 'user_agent': 'Mozilla/5...
# 1  {'platform': 'Win32', 'user_agent': 'Mozilla/5...
# 2  {'platform': 'Linux armv81', 'user_agent': 'Mo...
# 3  {'platform': 'Win32', 'user_agent': 'Mozilla/5...
# 4  {'platform': 'Win32', 'user_agent': 'Mozilla/5...
#
#                                       screen_context  \
# 0  {'avail_width': 1536, 'color_depth': 32, 'avai...
# 1  {'avail_width': 1536, 'color_depth': 32, 'avai...
# 2  {'avail_width': 384, 'color_depth': 24, 'avail...
# 3  {'avail_width': 1280, 'color_depth': 32, 'avai...
# 4  {'avail_width': 1280, 'color_depth': 32, 'avai...
#
#                                  network_information  \
# 0  {'rtt_ms': 250, 'save_data': False, 'downlink_...
# 1  {'rtt_ms': 200, 'save_data': False, 'downlink_...
# 2  {'rtt_ms': 100, 'save_data': False, 'downlink_...
# 3  {'rtt_ms': 100, 'save_data': False, 'downlink_...
# 4  {'rtt_ms': 100, 'save_data': False, 'downlink_...
#
#                                   battery_status  \
# 0  {'is_charging': False, 'battery_level': 0.96}
# 1  {'is_charging': False, 'battery_level': 0.76}
# 2  {'is_charging': False, 'battery_level': 0.77}
# 3      {'is_charging': True, 'battery_level': 1}
# 4      {'is_charging': True, 'battery_level': 1}
#
#                           timestamp                        created_at  \
# 0  2026-03-05 07:28:56.580000+00:00  2026-03-05 07:29:01.758897+00:00
# 1  2026-03-05 10:00:57.029000+00:00  2026-03-05 10:00:56.927949+00:00
# 2  2026-03-05 10:15:16.599000+00:00  2026-03-05 10:15:16.067975+00:00
# 3  2026-03-06 15:20:11.927000+00:00  2026-03-06 15:20:12.063691+00:00
# 4  2026-03-06 15:21:25.994000+00:00  2026-03-06 15:21:26.000699+00:00
#
#                                          device_info
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
# [5 rows x 24 columns]

# %%
amphi_positions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8701 entries, 0 to 8700
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   8701 non-null   int64
#  1   year                 8407 non-null   float64
#  2   section              0 non-null      float64
#  3   user                 1161 non-null   object
#  4   amphitheatre         8701 non-null   object
#  5   module               7834 non-null   object
#  6   seat_block           7152 non-null   object
#  7   seat_row             7152 non-null   float64
#  8   seat_column          7152 non-null   float64
#  9   latitude_mean        8701 non-null   float64
#  10  longitude_mean       8701 non-null   float64
#  11  accuracy_mean        8407 non-null   float64
#  12  gps_variance         8407 non-null   float64
#  13  is_outside           8701 non-null   bool
#  14  sample_count         8701 non-null   int64
#  15  raw_gps_readings     8701 non-null   object
#  16  collection_metadata  8701 non-null   object
#  17  navigator_context    8701 non-null   object
#  18  screen_context       8701 non-null   object
#  19  network_information  8701 non-null   object
#  20  battery_status       8701 non-null   object
#  21  timestamp            8701 non-null   object
#  22  created_at           8701 non-null   object
#  23  device_info          7834 non-null   object
# dtypes: bool(1), float64(8), int64(2), object(13)
# memory usage: 1.5+ MB
