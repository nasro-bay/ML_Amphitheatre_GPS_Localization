# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
amphi_positions=pd.read_csv(r"C:\Users\ASUS\Desktop\3y\S2\machine learning\Project\Local\Data\ensia_gps_data .csv")
print(amphi_positions.head())
# Out:
#    ID                         Timestamp  Year    Amphi                 Module  \
# 0  42  2026-03-09 19:33:41.279000+00:00     2  Amphi 2  Statistical Inference
# 1  41  2026-03-08 12:58:29.942000+00:00     4  Amphi 7        Computer Vision
# 2  40  2026-03-08 12:45:54.655000+00:00     4  Amphi 7        Computer Vision
# 3  39  2026-03-08 12:45:54.655000+00:00     4  Amphi 7        Computer Vision
# 4  38  2026-03-08 12:45:54.634000+00:00     4  Amphi 7        Computer Vision
#
#     Block  Row  Column   Lat_Mean  Lng_Mean    Acc_Mean   Variance  IsOutside  \
# 0  Center  3.0     1.0  36.686881  2.866843  114.000000   0.000000      False
# 1  Center  7.0     7.0  36.688334  2.866289   17.644699  10.333808      False
# 2   Right  3.0     1.0  36.688301  2.866227   20.000000   0.000000      False
# 3   Right  3.0     1.0  36.688301  2.866226   20.000000   0.000000      False
# 4   Right  3.0     1.0  36.688300  2.866226   20.000000   0.000000      False
#
# ...

# %%
amphi_positions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                41 non-null     int64
#  1   Timestamp         41 non-null     object
#  2   Year              41 non-null     int64
#  3   Amphi             41 non-null     object
#  4   Module            41 non-null     object
#  5   Block             34 non-null     object
#  6   Row               34 non-null     float64
#  7   Column            34 non-null     float64
#  8   Lat_Mean          41 non-null     float64
#  9   Lng_Mean          41 non-null     float64
#  10  Acc_Mean          41 non-null     float64
#  11  Variance          41 non-null     float64
#  12  IsOutside         41 non-null     bool
#  13  RawReadings       41 non-null     object
#  14  Metadata          41 non-null     object
#  15  NavigatorContext  41 non-null     object
# ...
